# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)
df = r.json()

df_pvl = pd.DataFrame(df['items'])
RJ_pvl = df_pvl[df_pvl['uf'] == 'RJ']
RJ_pvl
# Out:
#       id_pleito tipo_interessado         interessado  cod_ibge  uf  \
# 123       10266        Município  Armação dos Búzios   3300233  RJ
# 132        5054        Município     Duque de Caxias   3301702  RJ
# 167       12870        Município             Niterói   3303302  RJ
# 277       63612        Município             Resende   3304201  RJ
# 633       13271           Estado      Rio de Janeiro        33  RJ
# ...         ...              ...                 ...       ...  ..
# 4730      31436        Município           Nilópolis   3303203  RJ
# 4743       7273        Município      Rio de Janeiro   3304557  RJ
# 4846      31378        Município          Petrópolis   3303906  RJ
# 4983       5933           Estado      Rio de Janeiro        33  RJ
# 4996       5952           Estado      Rio de Janeiro        33  RJ
#
#                    num_pvl                                             status  \
# 123                   None                                       Regularizado
# 132                   None                                           Deferido
# 167                   None  Encaminhado à PGFN com manifestação técnica fa...
# 277   PVL02.008921/2022-14                    Em retificação pelo interessado
# 633                   None  Encaminhado à PGFN com manifestação técnica fa...
# ...                    ...                                                ...
# 4730  PVL02.000708/2019-69                                  Deferido (PVL-IF)
# 4743                  None                                           Deferido
# 4846  PVL02.000583/2019-77                                           Deferido
# 4983                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4996                  None                                           Deferido
#
#               num_processo        data_protocolo  \
# 123   17944.001158/2009-96  2010-04-12T03:00:00Z
# 132   17944.000031/2008-79  2008-03-27T03:00:00Z
# 167   17944.001832/2014-08  2016-03-16T03:00:00Z
# 277   17944.100828/2023-12  2023-08-24T17:59:04Z
# 633   17944.001999/2008-12  2009-07-01T03:00:00Z
# ...                    ...                   ...
# 4730                  None                  None
# 4743  17944.000536/2007-52  2007-05-30T03:00:00Z
# 4846  17944.101202/2019-39  2019-04-11T19:29:03Z
# 4983  17944.000237/2012-85  2012-04-16T03:00:00Z
# 4996  17944.000243/2012-32  2012-04-16T03:00:00Z
#
#                                           tipo_operacao  \
# 123                         Operação contratual interna
# 132                         Operação contratual interna
# 167   Operação contratual externa (com garantia da U...
# 277   Operação contratual interna (com garantia da U...
# 633   Operação contratual externa (com garantia da U...
# ...                                                 ...
# 4730                        Operação contratual interna
# 4743                        Operação contratual interna
# 4846                        Operação contratual interna
# 4983  Operação contratual externa (com garantia da U...
# 4996                        Operação contratual interna
#
#                                       finalidade  \
# 123   Regularização de Dívida - Energia Elétrica
# 132                     PAC - Pró-Moradia - 2008
# 167                  Desenvolvimento sustentável
# 277                               Infraestrutura
# 633                        Desenvolvimento rural
# ...                                          ...
# 4730                                       PNAFM
# 4743                       Saneamento para Todos
# 4846                                       PNAFM
# 4983                              Infraestrutura
# 4996                              Infraestrutura
#
#                                tipo_credor  \
# 123                    Empresa Não Estatal
# 132        Instituição Financeira Nacional
# 167   Instituição Financeira Internacional
# 277        Instituição Financeira Nacional
# 633   Instituição Financeira Internacional
# ...                                    ...
# 4730       Instituição Financeira Nacional
# 4743       Instituição Financeira Nacional
# 4846       Instituição Financeira Nacional
# 4983  Instituição Financeira Internacional
# 4996       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 123                        Ampla Energia e Serviços S/A           Real
# 132                             Caixa Econômica Federal           Real
# 167                        Corporação Andina de Fomento  Dólar dos EUA
# 277                                 Banco do Brasil S/A           Real
# 633   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# ...                                                 ...            ...
# 4730                            Caixa Econômica Federal           Real
# 4743                            Caixa Econômica Federal           Real
# 4846                            Caixa Econômica Federal           Real
# 4983                       Corporação Andina de Fomento  Dólar dos EUA
# 4996  Banco Nacional de Desenvolvimento Econômico e ...           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 123   1.208047e+06                 0                      0  10/05/2010
# 132   3.990000e+07                 0                      0  28/03/2008
# 167   1.000000e+08                 0                      0  28/03/2016
# 277   3.200000e+07                 0                      0  11/09/2023
# 633   3.950000e+07                 1                      0  07/07/2009
# ...            ...               ...                    ...         ...
# 4730  4.745739e+06                 0                      0  21/06/2019
# 4743  1.106480e+07                 1                      0  04/06/2007
# 4846  9.200000e+06                 1                      1  23/04/2019
# 4983  1.000000e+08                 1                      0  10/07/2012
# 4996  1.579545e+08                 1                      0  14/05/2012
#
# [70 rows x 18 columns]

# %%
# 2) Seu código aqui
RJ_pvl.status.value_counts()
# Out:
# Deferido                                                 29
# Encaminhado à PGFN com manifestação técnica favorável    13
# Arquivado                                                13
# Regularizado                                              5
# Arquivado por decurso de prazo                            4
# Deferido (PVL-IF)                                         4
# Em retificação pelo interessado                           1
# Em retificação pelo interessado (PVL-IF)                  1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
RJ_pvl['data_status'] = RJ_pvl['data_status'].astype(str)
RJ_pvl['ano_status'] = RJ_pvl['data_status'].str.split(pat='/').str.get(2)
RJ_pvl
# Out:
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8292\2700575328.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RJ_pvl['data_status'] = RJ_pvl['data_status'].astype(str)
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_8292\2700575328.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RJ_pvl['ano_status'] = RJ_pvl['data_status'].str.split(pat='/').str.get(2)
#       id_pleito tipo_interessado         interessado  cod_ibge  uf  \
# 123       10266        Município  Armação dos Búzios   3300233  RJ
# 132        5054        Município     Duque de Caxias   3301702  RJ
# 167       12870        Município             Niterói   3303302  RJ
# 277       63612        Município             Resende   3304201  RJ
# 633       13271           Estado      Rio de Janeiro        33  RJ
# ...         ...              ...                 ...       ...  ..
# 4730      31436        Município           Nilópolis   3303203  RJ
# 4743       7273        Município      Rio de Janeiro   3304557  RJ
# 4846      31378        Município          Petrópolis   3303906  RJ
# 4983       5933           Estado      Rio de Janeiro        33  RJ
# 4996       5952           Estado      Rio de Janeiro        33  RJ
#
#                    num_pvl                                             status  \
# 123                   None                                       Regularizado
# 132                   None                                           Deferido
# 167                   None  Encaminhado à PGFN com manifestação técnica fa...
# 277   PVL02.008921/2022-14                    Em retificação pelo interessado
# 633                   None  Encaminhado à PGFN com manifestação técnica fa...
# ...                    ...                                                ...
# 4730  PVL02.000708/2019-69                                  Deferido (PVL-IF)
# 4743                  None                                           Deferido
# 4846  PVL02.000583/2019-77                                           Deferido
# 4983                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4996                  None                                           Deferido
#
#               num_processo        data_protocolo  \
# 123   17944.001158/2009-96  2010-04-12T03:00:00Z
# 132   17944.000031/2008-79  2008-03-27T03:00:00Z
# 167   17944.001832/2014-08  2016-03-16T03:00:00Z
# 277   17944.100828/2023-12  2023-08-24T17:59:04Z
# 633   17944.001999/2008-12  2009-07-01T03:00:00Z
# ...                    ...                   ...
# 4730                  None                  None
# 4743  17944.000536/2007-52  2007-05-30T03:00:00Z
# 4846  17944.101202/2019-39  2019-04-11T19:29:03Z
# 4983  17944.000237/2012-85  2012-04-16T03:00:00Z
# 4996  17944.000243/2012-32  2012-04-16T03:00:00Z
#
#                                           tipo_operacao  \
# 123                         Operação contratual interna
# 132                         Operação contratual interna
# 167   Operação contratual externa (com garantia da U...
# 277   Operação contratual interna (com garantia da U...
# 633   Operação contratual externa (com garantia da U...
# ...                                                 ...
# 4730                        Operação contratual interna
# 4743                        Operação contratual interna
# 4846                        Operação contratual interna
# 4983  Operação contratual externa (com garantia da U...
# 4996                        Operação contratual interna
#
#                                       finalidade  \
# 123   Regularização de Dívida - Energia Elétrica
# 132                     PAC - Pró-Moradia - 2008
# 167                  Desenvolvimento sustentável
# 277                               Infraestrutura
# 633                        Desenvolvimento rural
# ...                                          ...
# 4730                                       PNAFM
# 4743                       Saneamento para Todos
# 4846                                       PNAFM
# 4983                              Infraestrutura
# 4996                              Infraestrutura
#
#                                tipo_credor  \
# 123                    Empresa Não Estatal
# 132        Instituição Financeira Nacional
# 167   Instituição Financeira Internacional
# 277        Instituição Financeira Nacional
# 633   Instituição Financeira Internacional
# ...                                    ...
# 4730       Instituição Financeira Nacional
# 4743       Instituição Financeira Nacional
# 4846       Instituição Financeira Nacional
# 4983  Instituição Financeira Internacional
# 4996       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 123                        Ampla Energia e Serviços S/A           Real
# 132                             Caixa Econômica Federal           Real
# 167                        Corporação Andina de Fomento  Dólar dos EUA
# 277                                 Banco do Brasil S/A           Real
# 633   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# ...                                                 ...            ...
# 4730                            Caixa Econômica Federal           Real
# 4743                            Caixa Econômica Federal           Real
# 4846                            Caixa Econômica Federal           Real
# 4983                       Corporação Andina de Fomento  Dólar dos EUA
# 4996  Banco Nacional de Desenvolvimento Econômico e ...           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status  \
# 123   1.208047e+06                 0                      0  10/05/2010
# 132   3.990000e+07                 0                      0  28/03/2008
# 167   1.000000e+08                 0                      0  28/03/2016
# 277   3.200000e+07                 0                      0  11/09/2023
# 633   3.950000e+07                 1                      0  07/07/2009
# ...            ...               ...                    ...         ...
# 4730  4.745739e+06                 0                      0  21/06/2019
# 4743  1.106480e+07                 1                      0  04/06/2007
# 4846  9.200000e+06                 1                      1  23/04/2019
# 4983  1.000000e+08                 1                      0  10/07/2012
# 4996  1.579545e+08                 1                      0  14/05/2012
#
#      ano_status
# 123        2010
# 132        2008
# 167        2016
# 277        2023
# 633        2009
# ...         ...
# 4730       2019
# 4743       2007
# 4846       2019
# 4983       2012
# 4996       2012
#
# [70 rows x 19 columns]

# %%
# 4)

RJ_pvl.ano_status.value_counts()
# Out:
# 2008    11
# 2007     9
# 2014     8
# 2009     6
# 2012     5
# 2010     4
# 2011     4
# 2023     4
# 2019     3
# 2015     3
# 2013     3
# 2016     2
# 2022     2
# 2017     1
# 2006     1
# 2018     1
# 2002     1
# 2004     1
# 2003     1
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
df_pvl
# Out:
#       id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0         42214        Município           Três Lagoas   5008305  MS
# 1         43025        Município          São Domingos   4216107  SC
# 2         45975        Município                Iguatu   4110052  PR
# 3         38819        Município           Horizontina   4309605  RS
# 4         39824        Município  Conceição do Almeida   2908309  BA
# ...         ...              ...                   ...       ...  ..
# 4995       5938        Município            Bananeiras   2501500  PB
# 4996       5952           Estado        Rio de Janeiro        33  RJ
# 4997       5974        Município                Sumaré   3552403  SP
# 4998      15165        Município                Modelo   4210902  SC
# 4999      15175        Município              Cascavel   4104808  PR
#
#                    num_pvl                           status  \
# 0     PVL02.000615/2020-78  Em retificação pelo interessado
# 1     PVL02.001515/2020-69                Deferido (PVL-IF)
# 2     PVL02.002106/2021-61                Deferido (PVL-IF)
# 3     PVL02.007531/2019-21                Deferido (PVL-IF)
# 4     PVL02.008455/2019-71                Deferido (PVL-IF)
# ...                    ...                              ...
# 4995                  None   Arquivado por decurso de prazo
# 4996                  None                         Deferido
# 4997                  None                     Regularizado
# 4998                  None                         Deferido
# 4999                  None                         Deferido
#
#               num_processo        data_protocolo  \
# 0     17944.101427/2020-29  2021-07-19T18:59:33Z
# 1                     None                  None
# 2                     None                  None
# 3                     None                  None
# 4                     None                  None
# ...                    ...                   ...
# 4995  17944.000239/2008-98  2008-04-07T03:00:00Z
# 4996  17944.000243/2012-32  2012-04-16T03:00:00Z
# 4997  17944.000247/2014-82  2021-01-22T20:21:56Z
# 4998  19406.000149/2004-96  2004-05-13T03:00:00Z
# 4999  19406.000150/2005-00  2005-12-15T02:00:00Z
#
#                                           tipo_operacao  \
# 0     Operação contratual externa (com garantia da U...
# 1                           Operação contratual interna
# 2                           Operação contratual interna
# 3                           Operação contratual interna
# 4                           Operação contratual interna
# ...                                                 ...
# 4995                        Operação contratual interna
# 4996                        Operação contratual interna
# 4997                        Operação contratual interna
# 4998                        Operação contratual interna
# 4999                        Operação contratual interna
#
#                                           finalidade  \
# 0                                     Infraestrutura
# 1                                     Infraestrutura
# 2                                      Plano Diretor
# 3                                     Infraestrutura
# 4     Aquisição de máquinas, equipamentos e veículos
# ...                                              ...
# 4995                               Caminho da Escola
# 4996                                  Infraestrutura
# 4997                Regularização de Dívida - Outros
# 4998                                  Infraestrutura
# 4999                                  Infraestrutura
#
#                                tipo_credor  \
# 0     Instituição Financeira Internacional
# 1          Instituição Financeira Nacional
# 2          Instituição Financeira Nacional
# 3          Instituição Financeira Nacional
# 4          Instituição Financeira Nacional
# ...                                    ...
# 4995       Instituição Financeira Nacional
# 4996       Instituição Financeira Nacional
# 4997                   Outras Organizações
# 4998       Instituição Financeira Nacional
# 4999       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 0                          Corporação Andina de Fomento  Dólar dos EUA
# 1                               Caixa Econômica Federal           Real
# 2                      Agência de Fomento do Paraná S/A           Real
# 3     BADESUL Desenvolvimento S.A. - Agência de Fome...           Real
# 4                                   Banco do Brasil S/A           Real
# ...                                                 ...            ...
# 4995                                Banco do Brasil S/A           Real
# 4996  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4997                                    Pessoa Jurídica           Real
# 4998  Agência de Fomento do Estado de Santa Catarina...           Real
# 4999                   Agência de Fomento do Paraná S/A           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0     5.000000e+07                 0                      0  23/07/2021
# 1     2.100000e+06                 0                      1  10/08/2020
# 2     1.200000e+05                 0                      1  18/05/2022
# 3     5.000000e+06                 0                      1  02/03/2020
# 4     9.500000e+05                 1                      1  27/12/2019
# ...            ...               ...                    ...         ...
# 4995  7.000000e+05                 0                      0  09/05/2008
# 4996  1.579545e+08                 1                      0  14/05/2012
# 4997  1.018848e+07                 0                      0  20/07/2021
# 4998  1.000000e+05                 0                      0  25/05/2004
# 4999  2.600000e+06                 1                      0  29/12/2005
#
# [5000 rows x 18 columns]

# %%
#1) Seu código aqui
def consulta_dado(uf, tipo_interessado):
    dados_consulta = df_pvl[(df_pvl['uf'] == uf) & (df_pvl['tipo_interessado'] == tipo_interessado)]
    return dados_consulta

uf = 'MG'
tipo_interessado = 'Estado'

resultado_consulta = consulta_dado(uf, tipo_interessado)

MG = pd.DataFrame(resultado_consulta)
MG
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 852        6811           Estado  Minas Gerais        31  MG
# 878       10011           Estado  Minas Gerais        31  MG
# 2329      13587           Estado  Minas Gerais        31  MG
# 2659      13672           Estado  Minas Gerais        31  MG
# 2972      13695           Estado  Minas Gerais        31  MG
# 3189      20458           Estado  Minas Gerais        31  MG
# 4041       9197           Estado  Minas Gerais        31  MG
#
#                    num_pvl                                             status  \
# 852                   None  Encaminhado à PGFN com manifestação técnica fa...
# 878                   None                                           Deferido
# 2329                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2659                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2972                  None                                          Arquivado
# 3189  00000.000000/2020-68                                 Arquivado a pedido
# 4041                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
# 852   17944.000435/2008-62  2008-03-06T03:00:00Z
# 878   17944.001099/2010-90  2010-08-23T03:00:00Z
# 2329  19405.000031/2004-78  2004-11-27T02:00:00Z
# 2659  19405.000048/2005-14  2005-12-28T02:00:00Z
# 2972  19405.000053/2003-57  2003-08-25T03:00:00Z
# 3189  17944.001085/2015-81  2015-11-23T02:00:00Z
# 4041  17944.000924/2009-03  2010-03-10T03:00:00Z
#
#                                           tipo_operacao  \
# 852   Operação contratual externa (com garantia da U...
# 878                         Operação contratual interna
# 2329  Operação contratual externa (com garantia da U...
# 2659  Operação contratual externa (com garantia da U...
# 2972  Operação contratual externa (com garantia da U...
# 3189  Operação contratual externa (com garantia da U...
# 4041  Operação contratual externa (com garantia da U...
#
#                  finalidade                           tipo_credor  \
# 852          Multissetorial  Instituição Financeira Internacional
# 878                    PMAE       Instituição Financeira Nacional
# 2329  Desenvolvimento rural  Instituição Financeira Internacional
# 2659         Multissetorial  Instituição Financeira Internacional
# 2972         Infraestrutura  Instituição Financeira Internacional
# 3189         Multissetorial  Instituição Financeira Internacional
# 4041         Infraestrutura  Instituição Financeira Internacional
#
#                                                  credor          moeda  \
# 852   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 878   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2329  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2659  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2972  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3189            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4041            Banco Interamericano de Desenvolvimento  Dólar dos EUA
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 852   9.760000e+08                 1                      0  02/07/2008
# 878   4.674243e+06                 1                      0  25/08/2010
# 2329  3.500000e+07                 1                      0  09/12/2004
# 2659  1.700000e+08                 1                      0  19/04/2006
# 2972  3.500000e+07                 0                      0  20/02/2004
# 3189  5.000000e+07                 0                      0  29/04/2016
# 4041  5.000000e+07                 1                      0  01/04/2010

# %%
# 2) Seu código aqui
MG.status.value_counts()

#resposta = 0 solicitações com o status pedido
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    4
# Deferido                                                 1
# Arquivado                                                1
# Arquivado a pedido                                       1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
BA_pvl = df_pvl[df_pvl['uf'] == 'BA']
BA_pvl_municipios = BA_pvl[BA_pvl['tipo_interessado'] == 'Município']

BA_pvl_municipios.interessado.value_counts()

#Irecê
# Out:
# Irecê                   5
# Teixeira de Freitas     4
# Itatim                  4
# Vitória da Conquista    4
# Baianópolis             4
#                        ..
# Dias d'Ávila            1
# Nordestina              1
# Mansidão                1
# Barra do Choça          1
# Mata de São João        1
# Name: interessado, Length: 149, dtype: int64

# %%
# 4) Seu código aqui

# %%
BA_pvl_estado = BA_pvl[BA_pvl['tipo_interessado'] == 'Estado']
BA_pvl_estado.to_csv('BA_pvl_ESTADO.csv', index = False, sep=';', decimal=',')
